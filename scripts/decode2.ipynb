# %%
import os, glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import read_cs_files as cs

# %%
def load_data(fname):
    # ... LOADING DATA FROM TOB FORMAT TO 10HZ
    # bin_data include 2 + N columns:
    # - The first column is the TIMESTAMP meta[2][0]
    # - The second column is the RECORD ID meta[2][1]
    # - Columns 3 to N+2 is the data with headers correspond to meta[2][2:-1]
    bin_data, meta = cs.read_cs_files(fname)
    
    # ... CONVERT DATA TO PANDAS FORMAT 
    df = pd.DataFrame(columns=meta[2], data=None)

    # Convert timestamp to datetimea:
    df['TIMESTAMP'] = pd.to_datetime(bin_data[0])

    # Copy the remaining data to dataframe
    for i, col in enumerate(meta[2][1:]):
        df[col] = bin_data[i + 1]    
        
    # Average the data into 30 minute frequency
    df_30min = df.resample('30T', on='TIMESTAMP').mean()
    df_30min.reset_index(inplace=True)
    
    df_1min = df.resample('1T', on='TIMESTAMP').mean()
    df_1min.reset_index(inplace=True)
    return df_30min, df_1min, df, meta

# %%
# filenames = sorted(glob.glob('ts_data*.dat'))
df_30min_all = pd.DataFrame()
df_1min_all = pd.DataFrame()
df_all = pd.DataFrame()
n0 = 0
n1 = 75
for i in range(n0,n1,1):
    fn = f'/Users/pvn/Downloads/Download-2025-08-25/ts_data{i}.dat'
    print(f'Processing file {i+1} of {n1-n0+1}: {fn}')
    df_30min, df_1min, df, meta = load_data(fn)
    df_30min_all = pd.concat([df_30min_all, df_30min], ignore_index=True)
    df_1min_all = pd.concat([df_1min_all, df_1min], ignore_index=True)
    df_all = pd.concat([df_all, df], ignore_index=True)
# Out:
# Processing file 1 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data0.dat
# Processing file 2 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data1.dat
# Processing file 3 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data2.dat
# Processing file 4 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data3.dat
# Processing file 5 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data4.dat
# Processing file 6 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data5.dat
# Processing file 7 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data6.dat
# Processing file 8 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data7.dat
# Processing file 9 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data8.dat
# Processing file 10 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data9.dat
# Processing file 11 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data10.dat
# Processing file 12 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data11.dat
# Processing file 13 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data12.dat
# Processing file 14 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data13.dat
# Processing file 15 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data14.dat
# Processing file 16 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data15.dat
# Processing file 17 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data16.dat
# Processing file 18 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data17.dat
# Processing file 19 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data18.dat
# Processing file 20 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data19.dat
# Processing file 21 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data20.dat
# Processing file 22 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data21.dat
# Processing file 23 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data22.dat
# Processing file 24 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data23.dat
# Processing file 25 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data24.dat
# Processing file 26 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data25.dat
# Processing file 27 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data26.dat
# Processing file 28 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data27.dat
# Processing file 29 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data28.dat
# Processing file 30 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data29.dat
# Processing file 31 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data30.dat
# Processing file 32 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data31.dat
# Processing file 33 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data32.dat
# Processing file 34 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data33.dat
# Processing file 35 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data34.dat
# Processing file 36 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data35.dat
# Processing file 37 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data36.dat
# Processing file 38 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data37.dat
# Processing file 39 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data38.dat
# Processing file 40 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data39.dat
# Processing file 41 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data40.dat
# Processing file 42 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data41.dat
# Processing file 43 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data42.dat
# Processing file 44 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data43.dat
# Processing file 45 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data44.dat
# Processing file 46 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data45.dat
# Processing file 47 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data46.dat
# Processing file 48 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data47.dat
# Processing file 49 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data48.dat
# Processing file 50 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data49.dat
# Processing file 51 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data50.dat
# Processing file 52 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data51.dat
# Processing file 53 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data52.dat
# Processing file 54 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data53.dat
# Processing file 55 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data54.dat
# Processing file 56 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data55.dat
# Processing file 57 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data56.dat
# Processing file 58 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data57.dat
# Processing file 59 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data58.dat
# Processing file 60 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data59.dat
# Processing file 61 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data60.dat
# Processing file 62 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data61.dat
# Processing file 63 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data62.dat
# Processing file 64 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data63.dat
# Processing file 65 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data64.dat
# Processing file 66 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data65.dat
# Processing file 67 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data66.dat
# Processing file 68 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data67.dat
# Processing file 69 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data68.dat
# Processing file 70 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data69.dat
# Processing file 71 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data70.dat
# Processing file 72 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data71.dat
# Processing file 73 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data72.dat
# Processing file 74 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data73.dat
# Processing file 75 of 76: /Users/pvn/Downloads/Download-2025-08-25/ts_data74.dat

# %%
colors = [
    "#4e79a7",  # deep blue
    "#f28e2b",  # vivid orange
    "#59a14f",  # fresh green
    "#e15759",  # bright red
    "#76b7b2",  # teal
    "#edc949",  # yellow
    "#af7aa1",  # muted purple
    "#ff9da7"   # soft pink
]

# %%
# import ipympl
names = meta[2]
units = meta[3]
vars = ['CO2', 'H2O', 'Temp', 'CH4D', 'Pressure', 'Ux', 'Uy', 'Uz']
fig, ax = plt.subplots(4, 2, figsize=(16,8), sharex=True)

for k, var in enumerate(vars):
    ind = names.index(var)
    label = f'{var} ({units[ind]})'
    m = k // 2
    n = k % 2
    ax[m,n].plot(df_all['TIMESTAMP'], df_all[var], colors[k])
    ax[m,n].set_title(label)
plt.suptitle('10Hz time series data', fontsize=16)
plt.tight_layout()
# plt.savefig('TS_data.png', dpi=600, bbox_inches='tight')

# %%
# import ipympl
names = meta[2]
units = meta[3]
vars = ['CH4D', 'Diag77', 'RSSI']
fig, ax = plt.subplots(3, 1, figsize=(16,8), sharex=True)

for k, var in enumerate(vars):
    ind = names.index(var)
    label = f'{var} ({units[ind]})'
    # m = k // 2
    # n = k % 2
    ax[k].plot(df_all['TIMESTAMP'], df_all[var], colors[k])
    ax[k].set_title(label)
# plt.suptitle('10Hz time series data', fontsize=16)
plt.tight_layout()
# plt.savefig('TS_data.png', dpi=600, bbox_inches='tight')

# %%
df_all.columns
# Out:
# Index(['TIMESTAMP', 'RECORD', 'Ux', 'Uy', 'Uz', 'SonicTemp', 'SonicDiag',
#        'CO2', 'H2O', 'irga(3)', 'irga_diag', 'CH4D', 'Pressure', 'Temp',
#        'Diag77', 'RSSI'],
#       dtype='object')

# %%
filename = '/Users/pvn/Downloads/eddypro_1_full_output_2025-08-28T112042_adv.csv'
df2 = pd.read_csv(filename, skiprows=4, header=None)

# %%
with open(filename, "r", encoding="latin-1") as f:
    meta_lines = [next(f) for _ in range(3)]  # header lines

# %%
columns =  meta_lines[1].strip().split(',')
columns = [c.strip('"') for c in columns]
df2.columns = columns
df2["datetime"] = pd.to_datetime(df2["date"] + " " + df2["time"])

units =  meta_lines[2].strip().split(',')
units = [u.strip('"') for u in units]

# %%
vars = ['LE', 'H', 'co2_flux', 'h2o_flux', 'ch4_flux']
colors = [
    "#4e79a7",  # deep blue
    "#f28e2b",  # vivid orange
    "#59a14f",  # fresh green
    "#e15759",  # bright red
    "#76b7b2",  # teal
    "#edc949",  # yellow
    "#af7aa1",  # muted purple
    "#ff9da7"   # soft pink
]

# %%
fig, ax = plt.subplots(len(vars), 1, figsize=(20, 2*len(vars)), sharex=True)
for k, var in enumerate(vars):
    u = units[columns.index(var)]
    data = df2[var]
    data[data == -9999] = np.nan
    ax[k].plot(df2['datetime'], data, colors[k])
    ax[k].set_title(f'{var} ({u})')
    # ax[k].set_title(f'Time series of {var}')
plt.xlabel('Time')
# Out:
# /var/folders/5t/zy7vw0s50pdbmspg54cwyj1mqbzrzg/T/ipykernel_71806/1095305088.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[data == -9999] = np.nan
# Text(0.5, 0, 'Time')
